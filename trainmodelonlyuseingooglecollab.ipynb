# %%
# # ===============================================
# #   Abschnitt 1 — Setup & YOLOv5 installieren
# # ===============================================

# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt

# # Google Colab Fix:
# import torch
# import os
# print("PyTorch version:", torch.__version__)
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17752, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 17752 (delta 72), reused 39 (delta 39), pack-reused 17635 (from 3)
# Receiving objects: 100% (17752/17752), 17.10 MiB | 14.80 MiB/s, done.
# Resolving deltas: 100% (12051/12051), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.6 MB/s eta 0:00:00
# ...
# PyTorch version: 2.9.0+cu126

# %%
# # =======================================================
# #   Abschnitt 2 — Deinen Datensatz von GitHub herunterladen
# # =======================================================

# # Klonen deines Repositorys
# !git clone https://github.com/LEisele22/BoardGameCV.git

# # In deinen Datensatz wechseln
# %cd BoardGameCV/training/dataset

# # Verzeichnis anzeigen
# !ls -R
# Out:
# Cloning into 'BoardGameCV'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 160 (delta 36), reused 136 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (160/160), 8.36 MiB | 6.28 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/yolov5/BoardGameCV/training/dataset
# .:
# train  valid
#
# ./train:
# images	labels
#
# ./train/images:
# board01.jpg   pieces02.jpg   pieces09.jpg   pieces16.jpg  pieces23.jpg
# board02.jpg   pieces03.jpg   pieces10.jpg   pieces17.jpg  pieces24.jpg
# board03.jpg   pieces04.jpg   pieces11.webp  pieces18.jpg  pieces25.jpg
# board04.jpg   pieces05.webp  pieces12.jpg   pieces19.jpg  pieces26.jpg
# board05.jpg   pieces06.jpg   pieces13.jpg   pieces20.jpg  pieces28.jpg
# board06.jpg   pieces07.jpg   pieces14.jpg   pieces21.jpg
# pieces01.jpg  pieces08.jpg   pieces15.jpg   pieces22.jpg
#
# ./train/labels:
# ...

# %%
# # =======================================================
# #   Abschnitt 3 — data.yaml automatisch erzeugen
# # =======================================================

# yaml_text = """
# train: ../BoardGameCV/training/dataset/train/images
# val: ../BoardGameCV/training/dataset/valid/images

# nc: 4
# names: ['board', 'whitefigure', 'blackfigure', 'emptyspot']
# """

# with open("/content/yolov5/data.yaml", "w") as f:
#     f.write(yaml_text)

# print("data.yaml erzeugt:")
# print(open("/content/yolov5/data.yaml").read())
# Out:
# data.yaml erzeugt:
#
# train: ../BoardGameCV/training/dataset/train/images
# val: ../BoardGameCV/training/dataset/valid/images
#
# nc: 4
# names: ['board', 'whitefigure', 'blackfigure', 'emptyspot']

# %%
# =======================================================
#   Abschnitt 4 — Training starten
# =======================================================

# %cd /content/yolov5

# !python train.py \
    --img 640 \
    --batch-size 8 \
    --epochs 50 \
    --data data.yaml \
    --weights yolov5s.pt \
    --project board_results \
    --name yolov5_board_detector
# Out:
# /content/yolov5
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-12-06 21:45:33.558851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765057533.578120     481 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# # =======================================================
# #   Abschnitt 6 — Inferenz auf Testbildern
# # =======================================================

# import glob
# test_images = glob.glob("/content/BoardGameCV/training/dataset/valid/images/*.jpg")
# print("Gefundene Testbilder:", len(test_images))

# !python detect.py \
#     --weights board_results/yolov5_board_detector/weights/best.pt \
#     --img 640 \
#     --source /content/BoardGameCV/training/dataset/valid/images \
#     --save-txt \
#     --save-conf
# Out:
# Gefundene Testbilder: 0
# detect: weights=['board_results/yolov5_board_detector/weights/best.pt'], source=/content/BoardGameCV/training/dataset/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-450-g781b9d57 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 436, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 431, in main
#     run(**vars(opt))
# ...

# %%
# =======================================================
#   Abschnitt 7 — Ergebnisse ansehen
# =======================================================

import glob
from IPython.display import Image

result_imgs = glob.glob("runs/detect/*/*.jpg")
print("Anzahl Ergebnisbilder:", len(result_imgs))

if len(result_imgs) > 0:
    display(Image(result_imgs[0]))
# Out:
# Anzahl Ergebnisbilder: 0

# %%
# =======================================================
#   Abschnitt 8 — Modell in ONNX exportieren
# =======================================================

# %cd /content/yolov5

# !python export.py \
    --weights board_results/yolov5_board_detector/weights/best.pt \
    --include onnx \
    --img 640 \
    --device cpu

print("ONNX Export abgeschlossen!")
# Out:
# /content/yolov5
# export: data=data/coco128.yaml, weights=['board_results/yolov5_board_detector/weights/best.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-450-g781b9d57 Python-3.12.12 torch-2.9.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from board_results/yolov5_board_detector/weights/best.pt with output shape (1, 25200, 9) (13.7 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxscript'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 8 packages in 553ms
# Prepared 3 packages in 1.16s
# Installed 3 packages in 265ms
#  + onnx==1.20.0
# ...
